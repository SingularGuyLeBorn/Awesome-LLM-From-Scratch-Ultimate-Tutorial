# %%
a = 1
print(a)
# Out:
# 1

# %%
import torch
import platform
import os

# 1. 检查操作系统和架构 (Colab通常是Linux)
print(f"OS/Architecture: {platform.platform()}")
print(f"TorchVersion: {torch.__version__}")


# 2. 检查 PyTorch 是否能找到 GPU
if torch.cuda.is_available():
    print(f"GPU Detected: {torch.cuda.get_device_name(0)}")
else:
    print("GPU not available.")
# Out:
# OS/Architecture: Linux-6.6.105+-x86_64-with-glibc2.35
# TorchVersion: 2.8.0+cu126
# GPU not available.
